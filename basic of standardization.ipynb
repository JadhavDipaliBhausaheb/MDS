# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
sns.kdeplot(data = df, x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'EstimatedSalary')
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>

# %%
np.round(df.describe())
# Out:
#           User ID    Age  EstimatedSalary  Purchased
# count       400.0  400.0            400.0      400.0
# mean   15691540.0   38.0          69742.0        0.0
# std       71658.0   10.0          34097.0        0.0
# min    15566689.0   18.0          15000.0        0.0
# 25%    15626764.0   30.0          43000.0        0.0
# 50%    15694342.0   37.0          70000.0        0.0
# 75%    15750363.0   46.0          88000.0        1.0
# max    15815236.0   60.0         150000.0        1.0

# %%
sns.scatterplot(data = df,x= 'EstimatedSalary',y ='Age')
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
df1 = sc.fit_transform(df[['EstimatedSalary','Age']])

# %%
df1
# Out:
# array([[-1.49004624, -1.78179743],
#        [-1.46068138, -0.25358736],
#        [-0.78528968, -1.11320552],
#        [-0.37418169, -1.01769239],
#        [ 0.18375059, -1.78179743],
#        [-0.34481683, -1.01769239],
#        [ 0.41866944, -1.01769239],
#        [ 2.35674998, -0.54012675],
#        [-1.07893824, -1.20871865],
#        [-0.13926283, -0.25358736],
#        [ 0.30121002, -1.11320552],
#        [-0.52100597, -1.11320552],
#        [ 0.47739916, -1.6862843 ],
#        [-1.51941109, -0.54012675],
#        [ 0.35993973, -1.87731056],
#        [ 0.30121002, -0.82666613],
#        [-1.3138571 ,  0.89257019],
#        [-1.28449224,  0.70154394],
#        [-1.22576253,  0.79705706],
#        [-1.19639767,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-0.60910054,  0.89257019],
#        [-0.84401939,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-1.37258681,  0.79705706],
#        [-1.46068138,  0.89257019],
#        [-1.22576253,  1.08359645],
# ...

# %%
sc.feature_names_in
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sc.feature_names_in
#
# AttributeError: 'StandardScaler' object has no attribute 'feature_names_in'

# %%
df1 = pd.DataFrames(df1,solumns=sc.feature_names_in)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df1 = pd.DataFrames(df1,solumns=sc.feature_names_in)
#
# AttributeError: module 'pandas' has no attribute 'DataFrames'

# %%
df1
# Out:
# array([[-1.49004624, -1.78179743],
#        [-1.46068138, -0.25358736],
#        [-0.78528968, -1.11320552],
#        [-0.37418169, -1.01769239],
#        [ 0.18375059, -1.78179743],
#        [-0.34481683, -1.01769239],
#        [ 0.41866944, -1.01769239],
#        [ 2.35674998, -0.54012675],
#        [-1.07893824, -1.20871865],
#        [-0.13926283, -0.25358736],
#        [ 0.30121002, -1.11320552],
#        [-0.52100597, -1.11320552],
#        [ 0.47739916, -1.6862843 ],
#        [-1.51941109, -0.54012675],
#        [ 0.35993973, -1.87731056],
#        [ 0.30121002, -0.82666613],
#        [-1.3138571 ,  0.89257019],
#        [-1.28449224,  0.70154394],
#        [-1.22576253,  0.79705706],
#        [-1.19639767,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-0.60910054,  0.89257019],
#        [-0.84401939,  0.98808332],
#        [-1.40195167,  0.70154394],
#        [-1.37258681,  0.79705706],
#        [-1.46068138,  0.89257019],
#        [-1.22576253,  1.08359645],
# ...

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(10,6)
ax1.scatter(df['Age'],df['EstimatedSalary'])
ax1.set_title("before scaling")
                             
ax2.scatter(df1['Age'],df1['EstimatedSalary'])
ax2.set_title("after scaling")
# Out:
#   Cell In[20], line 1
#     fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(10,6)
#                                 ^
# SyntaxError: '(' was never closed
