# %%
# matplotlib
#seaborn

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.randint(1,10,size = 10)
y = np.random.randint(1,10,size = 10)

# %%
plt.plot(x,y)

# %%
# subplots
fig, ax = plt.subplots()
ax.plot(x,y)
ax.plot(y,x)
ax.plot(x,x)
ax.plot(y,y)

# %%
#figure

fig = plt.figure()
#for single axes
fig, ax = plt.subplots()

fig, ax = plt.subplots(3,2)

fig, ax = plt.subplot_mosaic([['left','right_top','hello'],
                             ['left','right_bottom','hello']])

# %%
# first create some toy data:
x = np.linspace(0,2*np.pi,400)
y = np.sin(x**2)

# %%
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
f,(ax1,ax2) = plt.subplots(1,2, sharey=True)
ax1.plot(x,y)
ax1.set_title("Hello this is the first plot")
ax2.scatter(x,y)

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x,y)
axs[1,0].scatter(x,y)

# %%
x = np.linspace(0,2,1000)

# %%
fig,ax = plt.subplots(figsize = (8,4))
ax.plot(x,x, label = 'linear')
ax.plot(x,x**2,label = "square")
ax.plot(x,x**3,label = "cubic")

ax.set_xlabel("X label")
ax.set_ylabel("X label")
ax.set_title("basic of my data")
ax.legend()

# %%
fig,ax = plt.subplots(3,1)
ax[0].plot(x,x)
ax[1].plot(x,x**2)
ax[2].plot(x,x**3)

# %%
plt.scatter(x,x**2)

# %%
x = np.random.randint(1,10,size = 10)
y = np.random.randint(1,10,size = 10)

# %%
# color = ["red", 'green', 'black', 'yellow', 'orange', 'red', 'red', 'blue', 'green', 'black']
color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
plt.scatter(x,y,s = (50), c = color, marker='P', alpha=1)

# %%
a = [2,3,4,5]
b = list("ABCD")

plt.bar(b,a,width = .3,align = 'center')
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.random.randn(10)*100
x
# Out:
# array([ 171.87671346,  -95.449253  ,   51.20218247,  -20.08942239,
#        -143.75870506,  -71.29691336,   92.0618897 ,  155.47190008,
#         -73.59687909,  110.56306508])

# %%
plt.hist(x,bins=20)
# Out:
# (array([1., 0., 0., 1., 2., 0., 0., 1., 0., 0., 0., 0., 1., 0., 1., 0., 1.,
#         0., 1., 1.]),
#  array([-143.75870506, -127.97693414, -112.19516321,  -96.41339229,
#          -80.63162136,  -64.84985043,  -49.06807951,  -33.28630858,
#          -17.50453765,   -1.72276673,   14.0590042 ,   29.84077512,
#           45.62254605,   61.40431698,   77.1860879 ,   92.96785883,
#          108.74962975,  124.53140068,  140.31317161,  156.09494253,
#          171.87671346]),
#  <BarContainer object of 20 artists>)
